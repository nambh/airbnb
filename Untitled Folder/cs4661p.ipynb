# %%
# import needed library
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from xgboost.sklearn import XGBClassifier

# Draw inline
# %matplotlib inline

# Set figure aesthetics
sns.set_style("white", {'ytick.major.size': 10.0})
sns.set_context("poster", font_scale=1.1)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7f3e037415f8>>
# Traceback (most recent call last):
#   File "/home/sn/anaconda3/lib/python3.6/site-packages/xgboost/core.py", line 324, in __del__
#     _check_call(_LIB.XGDMatrixFree(self.handle))
# AttributeError: 'DMatrix' object has no attribute 'handle'

# %% [markdown]
# ## Data Exploration

# %%
# Read the data into DataFrams
train_users = pd.read_csv('train_users_2.csv')
test_users = pd.read_csv('test_users.csv')

# %%
# checking the training test
train_users.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
# ...

# %%
# checking the size of training dataset
train_users.shape
# Out:
# (213451, 16)

# %%
# checking the testing dataset
test_users.head()
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# ...

# %%
# checking the size of  testing dataset
test_users.shape
# Out:
# (62096, 15)

# %% [markdown]
# ## Missing Data

# %%
# Deal with Missing Data: Convert -unkown- in "gender" into NaN
train_users.gender.replace('-unknown-', np.nan, inplace=True)
test_users.gender.replace('-unknown-', np.nan, inplace=True)

# %%
# Compute the NaN percentage of each feature
users_nan = (train_users.isnull().sum() / train_users.shape[0]) * 100
tests_nan = (test_users.isnull().sum() / test_users.shape[0]) * 100

# %%
# The percentage of missing data in each colum in training data
print(users_nan)
# Out:
# id                          0.000000
# date_account_created        0.000000
# timestamp_first_active      0.000000
# date_first_booking         58.347349
# gender                     44.829024
# age                        41.222576
# signup_method               0.000000
# signup_flow                 0.000000
# language                    0.000000
# affiliate_channel           0.000000
# affiliate_provider          0.000000
# first_affiliate_tracked     2.841402
# signup_app                  0.000000
# first_device_type           0.000000
# first_browser               0.000000
# country_destination         0.000000
# dtype: float64

# %% [markdown]
# The feature date_first_booking has 58.35% of NaN or missing data, so to maximine our performing of our classifiers we will build we better not include this feature at the modeling part

# %%
# The percentage of missing data in each colum in testing data
print(tests_nan)
# Out:
# id                           0.000000
# date_account_created         0.000000
# timestamp_first_active       0.000000
# date_first_booking         100.000000
# gender                      54.418964
# age                         46.502190
# signup_method                0.000000
# signup_flow                  0.000000
# language                     0.000000
# affiliate_channel            0.000000
# affiliate_provider           0.000000
# first_affiliate_tracked      0.032208
# signup_app                   0.000000
# first_device_type            0.000000
# first_browser                0.000000
# dtype: float64

# %% [markdown]
# ### in both training and testing data set the feature age has a high rate of NaN

# %%
train_users.age.describe()
# Out:
# count    125461.000000
# mean         49.668335
# std         155.666612
# min           1.000000
# 25%          28.000000
# 50%          34.000000
# 75%          43.000000
# max        2014.000000
# Name: age, dtype: float64

# %%
test_users.age.describe()
# Out:
# count    33220.000000
# mean        37.616677
# std         74.440647
# min          1.000000
# 25%         26.000000
# 50%         31.000000
# 75%         40.000000
# max       2002.000000
# Name: age, dtype: float64

# %% [markdown]
# ### The statictis in both data sets shows the inconsistency in the age of the users.

# %%
print("Total number of users over 90 year olds is:", sum(test_users.age > 90)+sum(train_users.age > 90))
print("Total number of users less than 13 year olds is:", sum(test_users.age < 13)+sum(train_users.age < 13))
# Out:
# Total number of users over 90 year olds is: 2928
# Total number of users less than 13 year olds is: 59

# %%
# set the ouliers of age to NaN
train_users.loc[train_users.age > 90, 'age'] = np.nan
test_users.loc[test_users.age > 90, 'age'] = np.nan
train_users.loc[train_users.age < 13, 'age'] = np.nan
test_users.loc[test_users.age < 13, 'age'] = np.nan

# %%
# Merge train and test users
users = pd.concat((train_users, test_users), axis=0, ignore_index=True)
# Remove ID's 
users.drop('id',axis=1, inplace=True)
users.shape
# Out:
# (275547, 15)

# %%
# Print the first 5 rows
users.head()
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct   NaN                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaN               untracked
# 1           2011-05-25                NaN               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type  gender language signup_app  signup_flow  \
# 0        Chrome       Mac Desktop     NaN       en        Web            0
# ...

# %% [markdown]
# ### Visualizing the Data

# %% [markdown]
# ### Gender

# %%
users.gender.value_counts(dropna=False).plot(kind='bar', color='#c022d8', rot=0)
plt.xlabel('Gender')
sns.despine()

# %% [markdown]
# ####  The ammount of missing data is too many and  there is a slight difference between user gender.

# %% [markdown]
# ### Destination

# %%
destination_percentage = users.country_destination.value_counts() / users.shape[0] * 100
destination_percentage.plot(kind='bar',color='#2265d8', rot=0)
plt.xlabel('Destination Country')
plt.ylabel('Percentage')
sns.despine()

# %% [markdown]
# #### Age

# %%
sns.distplot(users.age.dropna(), color='#22d8b1')
plt.xlabel('Age')
sns.despine()

# %% [markdown]
# ### Date

# %%
categorical_features = [
    'affiliate_channel',
    'affiliate_provider',
    'country_destination',
    'first_affiliate_tracked',
    'first_browser',
    'first_device_type',
    'gender',
    'language',
    'signup_app',
    'signup_method'
]

for categorical_feature in categorical_features:
    users[categorical_feature] = users[categorical_feature].astype('category')
# transform dates into pandas date type
users['date_account_created'] = pd.to_datetime(users['date_account_created'])
users['date_first_booking'] = pd.to_datetime(users['date_first_booking'])
users['date_first_active'] = pd.to_datetime((users.timestamp_first_active // 1000000), format='%Y%m%d')

# %%
sns.set_style("whitegrid", {'axes.edgecolor': '0'})
sns.set_context("poster", font_scale=1.0)
users.date_account_created.value_counts().plot(kind='line', linewidth=1.2, color='#FD5C64')
plt.show()

# %%
users.date_first_active.value_counts().plot(kind='line', linewidth=1.2, color='#FD5C64')
plt.show()

# %%
users.date_first_booking.value_counts().plot(kind='line', linewidth=1.2, color='#FD5C64')
plt.show()

# %%
date = pd.to_datetime(20140101, format='%Y%m%d')

before = sum(users.loc[users['date_first_active'] < date, 'country_destination'].value_counts())
before_destinations = users.loc[users['date_first_active'] < date, 
                                'country_destination'].value_counts() / before * 100
before_destinations.plot(kind='bar',  color='#2822d8', position=0, label='Before 2014', rot=0)

after = sum(users.loc[users['date_first_active'] > date, 'country_destination'].value_counts())
after_destinations = users.loc[users['date_first_active'] > date, 
                               'country_destination'].value_counts() / after * 100
after_destinations.plot(kind='bar',  color='#22d8b1', position=1, label='After 2014', rot=0)

plt.legend()
plt.xlabel('Destination Country')
plt.ylabel('Percentage')
sns.despine()
plt.show()

# %% [markdown]
# ## Predict

# %%
# Create label and id_test vector
labels = train_users['country_destination']
id_test = test_users['id']
# train_users = train_users.drop(['country_destination'], axis=1)
end_train = train_users.shape[0]

# %%
# #Creating a DataFrame with train+test data
# df_all = pd.concat((train_users, test_users), axis=0, ignore_index=True)
# #Removing id and date_first_booking
# df_all = df_all.drop(['id', 'date_first_booking'], axis=1)
# #Filling nan
# df_all = df_all.fillna(-1)

# %%
users.head()
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct   NaN                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaT               untracked
# 1           2011-05-25                NaT               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type  gender language signup_app  signup_flow  \
# 0        Chrome       Mac Desktop     NaN       en        Web            0
# ...

# %%
# Remove 'country_destination' 
users.drop('country_destination',axis=1, inplace=True)

# %%
users.head()
# Out:
#   affiliate_channel affiliate_provider   age date_account_created  \
# 0            direct             direct   NaN           2010-06-28
# 1               seo             google  38.0           2011-05-25
# 2            direct             direct  56.0           2010-09-28
# 3            direct             direct  42.0           2011-12-05
# 4            direct             direct  41.0           2010-09-14
#
#   date_first_booking first_affiliate_tracked first_browser first_device_type  \
# 0                NaT               untracked        Chrome       Mac Desktop
# 1                NaT               untracked        Chrome       Mac Desktop
# 2         2010-08-02               untracked            IE   Windows Desktop
# 3         2012-09-08               untracked       Firefox       Mac Desktop
# 4         2010-02-18               untracked        Chrome       Mac Desktop
#
#    gender language signup_app  signup_flow signup_method  \
# ...

# %%
# Remove 'date_first_booking' 
users.drop('date_first_booking',axis=1, inplace=True)

# %%
users.head()
# Out:
#   affiliate_channel affiliate_provider   age date_account_created  \
# 0            direct             direct   NaN           2010-06-28
# 1               seo             google  38.0           2011-05-25
# 2            direct             direct  56.0           2010-09-28
# 3            direct             direct  42.0           2011-12-05
# 4            direct             direct  41.0           2010-09-14
#
#   first_affiliate_tracked first_browser first_device_type  gender language  \
# 0               untracked        Chrome       Mac Desktop     NaN       en
# 1               untracked        Chrome       Mac Desktop    MALE       en
# 2               untracked            IE   Windows Desktop  FEMALE       en
# 3               untracked       Firefox       Mac Desktop  FEMALE       en
# 4               untracked        Chrome       Mac Desktop     NaN       en
#
#   signup_app  signup_flow signup_method  timestamp_first_active  \
# ...

# %%
id_test = test_users['id']
end_train = train_users.shape[0]
# users = users.fillna(-1)

# %% [markdown]
# #### for "NaN", find the value that is most common in the column it is found and replace the "NaN" with it

# %%
categorical_features = [
    'affiliate_channel',
    'affiliate_provider',
    'first_affiliate_tracked',
    'first_browser',
    'first_device_type',
    'gender',
    'language',
    'signup_app',
    'signup_method'
]
fcc_list = len(categorical_features)
from collections import Counter
print("The most common in the column")
for i in range(fcc_list):
    lst = users[categorical_features[i]]
    data = Counter(lst)
    most_common = max(lst, key=data.get)  
    print("most_common:",most_common) 
    users[categorical_features[i]].replace(" NaN", most_common, inplace=True)
# Out:
# The most common in the column
# most_common: direct
# most_common: direct
# most_common: untracked
# most_common: Chrome
# most_common: Mac Desktop
# most_common: nan
# most_common: en
# most_common: Web
# most_common: basic

# %%
# Replace NaN in age by the average of its column
users.age.fillna(users.age.mean(), inplace =True)

# %%
users.head()
# Out:
#   affiliate_channel affiliate_provider        age date_account_created  \
# 0            direct             direct  35.963871           2010-06-28
# 1               seo             google  38.000000           2011-05-25
# 2            direct             direct  56.000000           2010-09-28
# 3            direct             direct  42.000000           2011-12-05
# 4            direct             direct  41.000000           2010-09-14
#
#   first_affiliate_tracked first_browser first_device_type  gender language  \
# 0               untracked        Chrome       Mac Desktop     NaN       en
# 1               untracked        Chrome       Mac Desktop    MALE       en
# 2               untracked            IE   Windows Desktop  FEMALE       en
# 3               untracked       Firefox       Mac Desktop  FEMALE       en
# 4               untracked        Chrome       Mac Desktop     NaN       en
#
#   signup_app  signup_flow signup_method  timestamp_first_active  \
# ...

# %%
#One-hot-encoding features
for f in categorical_features:
    users_dummy = pd.get_dummies(users[f], prefix=f)
    users = users.drop([f], axis=1)
    users = pd.concat((users, users_dummy), axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
from xgboost.sklearn import XGBClassifier
np.random.seed(0)
# Splitting train and test
vals = users.values
X = vals[:end_train]
le = LabelEncoder()
y = le.fit_transform(labels)   
X_testing = vals[end_train:]

# %%
#timestamp date_account_created
dac = np.vstack(users.date_account_created.astype(str).apply(lambda x: list(map(int, x.split('-')))).values)
users['dac_year'] = dac[:,0]
users['dac_month'] = dac[:,1]
users['dac_day'] = dac[:,2]
users = users.drop(['date_account_created'], axis=1)

# %%
#timestamp_first_active
tfa = np.vstack(users.timestamp_first_active.astype(str).apply(lambda x: list(map(int, [x[:4],x[4:6],x[6:8],x[8:10],x[10:12],x[12:14]]))).values)
users['tfa_year'] = tfa[:,0]
users['tfa_month'] = tfa[:,1]
users['tfa_day'] = tfa[:,2]
users = users.drop(['timestamp_first_active'], axis=1)

# %%
users.head()
# Out:
#          age  signup_flow date_first_active  affiliate_channel_api  \
# 0  35.963871            0        2009-03-19                      0
# 1  38.000000            0        2009-05-23                      0
# 2  56.000000            3        2009-06-09                      0
# 3  42.000000            0        2009-10-31                      0
# 4  41.000000            0        2009-12-08                      0
#
#    affiliate_channel_content  affiliate_channel_direct  \
# 0                          0                         1
# 1                          0                         0
# 2                          0                         1
# 3                          0                         1
# 4                          0                         1
#
#    affiliate_channel_other  affiliate_channel_remarketing  \
# 0                        0                              0
# 1                        0                              0
# ...

# %%
users = users.drop(['date_first_active'], axis=1)

# %%
users.head()
# Out:
#          age  signup_flow  affiliate_channel_api  affiliate_channel_content  \
# 0  35.963871            0                      0                          0
# 1  38.000000            0                      0                          0
# 2  56.000000            3                      0                          0
# 3  42.000000            0                      0                          0
# 4  41.000000            0                      0                          0
#
#    affiliate_channel_direct  affiliate_channel_other  \
# 0                         1                        0
# 1                         0                        0
# 2                         1                        0
# 3                         1                        0
# 4                         1                        0
#
#    affiliate_channel_remarketing  affiliate_channel_sem-brand  \
# 0                              0                            0
# ...

# %%
# Divide the training data into a training and test set
from sklearn.model_selection import train_test_split
# y = users['country_destination']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
# # Classifier
xgb = XGBClassifier(max_depth=6, learning_rate=0.3, n_estimators=25,
                    objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)                  
xgb.fit(X, y)
y_pred = xgb.predict_proba(X_test)
# Out:
# --------------------------------------------
# TypeError  Traceback (most recent call last)
# <ipython-input-158-07b85ebe7f52> in <module>()
#       2 xgb = XGBClassifier(max_depth=6, learning_rate=0.3, n_estimators=25,
#       3                     objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)
# ----> 4 xgb.fit(X, y)
#       5 y_pred = xgb.predict_proba(X_test)
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose)
#     437         else:
#     438             train_dmatrix = DMatrix(X, label=training_labels,
# --> 439                                     missing=self.missing)
#     440
#     441         self._Booster = train(xgb_options, train_dmatrix, self.n_estimators,
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
my_RandomForest = RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=2)
my_RandomForest.fit(X_train, y_train)

y_training = my_RandomForest.predict(X_train)
acc_train = accuracy_score(y_train, y_training)

y_predict = my_RandomForest.predict(X_test)
acc_test = accuracy_score(y_test, y_predict)

print("Accuracy on training data:", acc_train)
print("Accuracy on test data:", acc_test)
# Out:
# --------------------------------------------
# TypeError  Traceback (most recent call last)
# <ipython-input-110-3c1e1267a950> in <module>()
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 my_RandomForest = RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=2)
# ----> 4 my_RandomForest.fit(X_train, y_train)
#       5
#       6 y_training = my_RandomForest.predict(X_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ...
